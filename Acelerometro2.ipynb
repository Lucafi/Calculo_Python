# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# https://apps.apple.com/us/app/ncsumytech/id1022359361

# %%
df=pd.read_csv("/Users/luizcarlosfigueiredo/OneDrive/Aulas/MoviesAulas/Calculo/elevador.csv",sep=";")

# %%
df.head(65)
# Out:
#           t     x     y     Z
# 0     0.000 -0.02  0.12  0.01
# 1    13.000 -0.02  0.11  0.01
# 2    29.000 -0.05  0.15 -0.07
# 3    48.000  0.01  0.09 -0.09
# 4    63.000  0.00  0.05 -0.14
# ..      ...   ...   ...   ...
# 60  996.000  0.06 -0.05  0.22
# 61    1.013 -0.07  0.05  0.28
# 62    1.030 -0.11  0.04  0.15
# 63    1.046 -0.05  0.06  0.05
# 64    1.062 -0.12  0.01  0.00
#
# [65 rows x 4 columns]

# %%
df=df.loc[61:2508]
plt.plot(df['t'],df['Z'])
plt.grid()

# %%
t=np.array(df['t']) 
Z=np.array(df['Z'])

# %%
n=len(t)

# %%
t[0]
# Out:
# 1.013

# %%
t[n-1]
# Out:
# 41.79600000000001

# %%
t=t-t[0]
t[0]
# Out:
# 0.0

# %%
Z[0]
# Out:
# 0.28

# %%
Z[n-1]
# Out:
# 0.01

# %%
Z=Z-(Z[0]/t[n-1])

# %%
Z[0]
# Out:
# 0.2731343942328912

# %%
Z[n-1]
# Out:
# 0.0031343942328911564

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=t[0]
b=t[n-1]
d=(b-a)/n
I=d*(((Z[0]+Z[n-1])/2)+np.sum(Z)-Z[0]-Z[n-1])
I
# Out:
# 0.606357182263997

# %%
vel=np.cumsum(Z*d)
plt.plot(t,vel)
plt.grid()

# %%
m = (vel[n-1]-vel[0])/(t[n-1]-t[0])
q=vel[0]
velcor= vel-(m*t+q)
plt.plot(t,velcor)
plt.grid()

# %%
a1=t[0]
b1=t[n-1]
d1=(b-a)/n
Il=d1*(((velcor[0]+velcor[n-1])/2)+np.sum(velcor)-velcor[0]-velcor[n-1])
Il
# Out:
# 31.250133079367583

# %%
t=t[200:2195]
t=t-t[0]
velcor=velcor[200:2195]
plt.plot(t,velcor)
plt.grid()

# %%
n=len(t)
tempo=(t[n-1]-t[0])
tempo
vm=Il/tempo
print("A velocidade média é: %4.2f" %vm, "m/s")
# Out:
# A velocidade média é: 0.94 m/s

# %%
l=np.cumsum(velcor*d1)
plt.plot(l,t)
plt.grid()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
yd=np.zeros_like(t)
a=t[0]
N=len(t)
b=t[n-1]
dx=(b-a)/(N)

for i in range(N):
    if i==0:
        yd[i]=(velcor[i+1]-velcor[i])/dx
    elif i==N-1:
        yd[i]=(velcor[i]-velcor[i-1])/dx
    else:
        yd[i]=(velcor[i+1]-velcor[i-1])/(2*dx)

# %%
Z=Z[200:2195]
plt.plot(t,yd, label='Aceleração corrigida')
plt.plot(t,Z, label='Aceleração')
plt.legend()
plt.grid()

# %%
plt.plot(t,Z, label='Aceleração')
plt.plot(t,yd, label='Aceleração corrigida')
plt.legend()
